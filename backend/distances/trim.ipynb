# %%
import pandas as pd

df = pd.read_csv('distances_7.csv', index_col=0)
df_trimmed = df.iloc[:23, :23]
df_trimmed
# Out:
#                                        This couldn't possibly work.  \
# This couldn't possibly work.                               0.000000
# This can't work.                                           0.236580
# This will never work.                                      0.433096
# This might not really work.                                0.313185
# This computer doesn't work.                                0.631094
# This couldn't really work.                                 0.120181
# This just might work.                                      0.437709
# This won't fail to work.                                   0.450757
# This won't really work.                                    0.405252
# This cat is doing some work.                               0.954056
# This wouldn't really work.                                 0.298832
# This wasn't the right way to work.                         0.511658
# This was a really good work.                               0.755470
# ...

# %%
df_trimmed.to_csv('distances_7_2.csv')
